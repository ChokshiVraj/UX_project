# %%
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
y= ["Vaitamins A supplementation","Continued breastfeeding","Exculsive breastfeeding","Early initiaition of breastfeeding","Diarrhoea treatmentL ORS","Careseekign for symptoms of pneumonia","Immuization - Measles","Immunization - DPT3","Postnatal care for babies","Postnatal car for mothers","Skilled attendant ","Neonatal Tetanus "," Antenatal Care"," Demand for family planning"]
x=[34.30,10.60,32.90,26.90,31.50,7.60,48.9,56.7,52.8,45.3,45,41.3,86.1,49.4]
x1 = [34.30 ,11.00 ,33.10 ,39.70 ,33.10 ,9.20 ,52.10 ,56.80 ,65.60 ,48.30 ,40.70 ,40.40 ,75.10 ,44.10]

x2=[33.5 ,13.9 ,32.5 ,47.1 ,35.9 ,8.5 ,54.4 ,53.7 ,56.3 ,45 ,41 ,45.8 ,79.6 ,"NaN"]
x3=[40.2 ,19.3 ,35.1 ,68.6 ,41.4 ,7.6 ,64.7 ,65 ,66.8 ,50.1 ,42.5 ,48.1 ,77.5 ,51.6]
x4=[51 ,35.5 ,33.9 ,88 ,57.7 ,14.3 ,70.4 ,69.3 ,70 ,42.1 ,35.4 ,40.5 ,74.5 ,"NaN"]
plt.figure(figsize=(8, 6), dpi=80)

plt.scatter(x,y, marker='o', label='Q1 - Poorest')
plt.legend()
plt.scatter(x1,y, marker='v',label='Q2')
plt.legend()
plt.scatter(x2, y, marker='s',label='Q3')
plt.scatter(x3, y, marker='p',label='Q4')
plt.scatter(x4, y, marker='*', label='Q5 - Wealthiest')
plt.grid(axis='y')
plt.xticks(np.arange(0, 120, 20))

plt.xlabel(xlabel='%Coverage')

plt.legend(bbox_to_anchor=(1.45, 1.0), loc='upper right')
plt.tight_layout()
plt.show()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
y= ["Vaitamins A supplementation","Continued breastfeeding","Exculsive breastfeeding","Early initiaition of breastfeeding","Diarrhoea treatmentL ORS","Careseekign for symptoms of pneumonia","Immuization - Measles","Immunization - DPT3","Postnatal care for babies","Postnatal car for mothers","Skilled attendant ","Neonatal Tetanus "," Antenatal Care"," Demand for family planning"]
rural=[36.2,13.3,34.4,45.8,36.1,8.3,55.2,57.9,60.3,47.1,41.9,44.0,78.5,47.5]

urban = [34.30 ,11.00 ,33.10 ,39.70 ,33.10 ,9.20 ,52.10 ,56.80 ,65.60 ,48.30 ,40.70 ,40.40 ,75.10 ,44.10]

x2=[33.5 ,13.9 ,32.5 ,47.1 ,35.9 ,8.5 ,54.4 ,53.7 ,56.3 ,45 ,41 ,45.8 ,79.6 ,41.7]
x3=[40.2 ,19.3 ,35.1 ,68.6 ,41.4 ,7.6 ,64.7 ,65 ,66.8 ,50.1 ,42.5 ,48.1 ,77.5 ,51.6]
x4=[51 ,35.5 ,33.9 ,88 ,57.7 ,14.3 ,70.4 ,69.3 ,70 ,42.1 ,35.4 ,40.5 ,74.5 ,51]
plt.figure(figsize=(8, 6), dpi=80)




plt.scatter(rural, y,label='rural')
plt.scatter(urban, y, marker='*', label='urban')
plt.legend()
plt.grid(axis='y')
plt.xticks(np.arange(0, 120, 20))

plt.xlabel(xlabel='%Coverage')

plt.legend(bbox_to_anchor=(1.20, 1.0), loc='upper right')
plt.tight_layout()
plt.show()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
y= ["Improved source of drinking water - urban","Improved source of drinking water - rural","Immunization DPT3 - urban","Immunization DPT3 - rural","Skilled attendant - urban","Skilled attendant - rural", "Demand for family planning - urban", " Demand for family planning - rural"]

x1 =[60, 39, 75, 45, 43, 24, 18, 37]
x2=[62, 55, 40, 52, 70, 39, 37, 37]
x3=[64, 70, 62, 55, 70, 44, 35, 38]
x4=[80,79, 67, 63, 67, 68, 43, 47]
x5=[90, 88, 67, 80, 88, 90, 55, 49]
plt.figure(figsize=(8, 6), dpi=80)



plt.scatter(x1,y, marker='o', label='Q1 - Poorest')
plt.legend()
plt.scatter(x2,y, marker='v',label='Q2')
plt.legend()
plt.scatter(x3, y, marker='s',label='Q3')
plt.scatter(x4, y, marker='p',label='Q4')
plt.scatter(x5, y, marker='*', label='Q5 - Wealthiest')
plt.grid(axis='y')
plt.xticks(np.arange(0, 120, 20))

plt.xlabel(xlabel='%Coverage')

plt.legend(bbox_to_anchor=(1.45, 1.0), loc='upper right')
plt.tight_layout()
plt.show()
plt.show()
